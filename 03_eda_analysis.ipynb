# %% [markdown]
# # 03 EDA Analysis
#
# Exploratory analysis of NAV, AUM, SIP, category flows, investor demographics, geography, folios, correlations, and sector allocation.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "data").exists() and (PROJECT_ROOT.parent / "data").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
RAW_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
REPORTS_DIR = PROJECT_ROOT / "reports"
CHARTS_DIR = REPORTS_DIR / "charts"
sns.set_theme(style="whitegrid")
PROJECT_ROOT

# %%
from IPython.display import Image, display
chart_files = sorted(CHARTS_DIR.glob("*.png"))
len(chart_files), [p.name for p in chart_files[:5]]

# %%
for path in chart_files:
    print(path.name)
    display(Image(filename=str(path), width=900))

# %% [markdown]
# ## 10 Key EDA Findings
#
# **Insight 1:** The raw fund universe contains 40 schemes across 10 AMCs; see Chart 01 for all-scheme NAV movement.
#
# **Insight 2:** Processed NAV covers 2022-01-03 to 2026-05-29 with 18,320 weekend/holiday forward-filled rows; see Chart 01.
#
# **Insight 3:** SIP inflows peaked at Rs 31,002 Cr in Dec 2025; see Chart 03.
#
# **Insight 4:** SBI Mutual Fund leads latest AMC AUM at 12.50 lakh crore; see Chart 02.
#
# **Insight 5:** Industry folios grew from 13.26 Cr to 26.12 Cr, a 97.0% increase; see Chart 12.
#
# **Insight 6:** Madhya Pradesh contributes the highest SIP amount in the transaction sample; see Chart 08.
#
# **Insight 7:** The highest average SIP ticket is from age group 56+; see Chart 06.
#
# **Insight 8:** Male investors are the largest gender segment at 66.5% of transactions; see Chart 07.
#
# **Insight 9:** Liquid is the strongest FY25 category by net inflow at Rs 451,275 Cr; see Chart 04.
#
# **Insight 10:** Banking is the largest aggregate sector exposure, while Mirae Asset Large Cap Fund - Regular - Growth ranks highest on the composite scorecard; see Charts 14 and 16.
#
# **Advanced risk note:** ABSL Small Cap Fund - Regular - Growth has the deepest 95% daily VaR in the computed report; see Chart 18.
